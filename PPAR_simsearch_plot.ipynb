# %% [markdown]
# mols2grid 설치

# %%
# !pip install rdkit mols2grid
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.1 MB/s eta 0:00:00
# ...

# %%
from pathlib import Path
import pandas as pd
from rdkit import RDConfig
import matplotlib.pyplot as plt
import mols2grid
from IPython.display import display
from ipywidgets import widgets

# %% [markdown]
# 나의 파일로 시도 & 커스터마이징

# %%
pip install openpyxl #xlsx 확장자 사용시 필요

# %%
import pandas as pd

data_smi = pd.read_csv('top10K_data.csv')
data_50=data_smi.head(50)

# %%
data_50
# Out:
#    Enam_CatalogID                                        Enam_SMILES  \
# 0     Z4514488716  Cc1c(C)n(Cc2cccc(OC(C)(C)C(=O)O)c2)c2ccc(C(=O)...
# 1     Z1255386783                          CC(C)(C)c1cc(C(=O)O)ccc1O
# 2       Z56763633                          CC(=O)c1ccc(Oc2ccccc2)cc1
# 3      Z277540126                  CC(=O)c1ccc(Oc2ccc(C(=O)O)cc2)cc1
# 4      Z104483428                            COc1ccc(O)c(C(C)(C)C)c1
# 5      Z362803202                          CC(=O)c1ccc(OC(C)(C)C)cc1
# 6      Z332381850                      CC(=O)c1ccc(Oc2ccc(Cl)cc2)cc1
# 7     Z3832200097         CC(=O)N1CCN(C(=O)c2ccc(O)c(C(C)(C)C)c2)CC1
# 8      Z332381826                      CC(=O)c1ccc(Oc2ccc(Br)cc2)cc1
# 9      Z332381946                       CC(=O)c1ccc(Oc2ccc(F)cc2)cc1
# 10      Z85956680                           CC(=O)c1ccc(C(C)(C)C)cc1
# 11    Z1613964494       CC(=O)c1ccc(O)c(NC(=O)c2cccc(Oc3ccccc3)c2)c1
# 12    Z1147898989           C[C@H](NC(=O)c1ccc(C(C)(C)C)cc1)c1ccccc1
# ...

# %%
mols2grid.display(data_50, smiles_col="Enam_SMILES", size=(200,200),prerender=True,useSVG=True)
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
# ...

# %%
mols2grid.display(data_50, smiles_col="Enam_SMILES", size=(200,200),
                  prerender=True,useSVG=True,
                  n_items_per_page=12,
                  subset=["Enam_CatalogID", "img","Total_Similarity"],
                  fontsize=20)
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
# ...
